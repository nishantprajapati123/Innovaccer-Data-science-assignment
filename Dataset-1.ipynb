# %%
#Innovaccer internship submission
#Dataset-1
"""
Intern_Name: Nishant prajapati
College : National Institute of Technology, Rourkela
Year : 3rd
Department: Computer Science and Engineering
Github: https://github.com/nishantprajapati123
LinkedIn: https://www.linkedin.com/in/nishant-prajapati-11253b152/
HackerRank : https://www.hackerrank.com/Nishant_2017
FaceBook : https://www.facebook.com/nishant.kumar.7121614

"""
#importing required library
import warnings
warnings.filterwarnings('ignore')
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import model_selection, preprocessing
color = sns.color_palette()
# %matplotlib inline

# %% [markdown]
# # Exploratory Data Analysis

# %%
#import excel file
df=pd.read_excel("dataset1.xlsx")

# %%
#basic information about dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 20 columns):
# User country         504 non-null object
# Nr. reviews          504 non-null int64
# Nr. hotel reviews    504 non-null int64
# Helpful votes        504 non-null int64
# Score                504 non-null int64
# Period of stay       504 non-null object
# Traveler type        504 non-null object
# Swimming Pool        504 non-null object
# Exercise Room        504 non-null object
# Basketball Court     504 non-null object
# Yoga Classes         504 non-null object
# Club                 504 non-null object
# Free Wifi            504 non-null object
# Hotel name           504 non-null object
# Hotel stars          504 non-null object
# Nr. rooms            504 non-null int64
# User continent       504 non-null object
# Member years         504 non-null int64
# Review month         504 non-null object
# Review weekday       504 non-null object
# dtypes: int64(6), object(14)
# ...

# %%
#statistical description of data
df.describe()
# Out:
#        Nr. reviews  Nr. hotel reviews  Helpful votes       Score    Nr. rooms  \
# count   504.000000         504.000000     504.000000  504.000000   504.000000
# mean     48.130952          16.023810      31.751984    4.123016  2196.380952
# std      74.996426          23.957953      48.520783    1.007302  1285.476807
# min       1.000000           0.000000       0.000000    1.000000   188.000000
# 25%      12.000000           5.000000       8.000000    4.000000   826.000000
# 50%      23.500000           9.000000      16.000000    4.000000  2700.000000
# 75%      54.250000          18.000000      35.000000    5.000000  3025.000000
# max     775.000000         263.000000     365.000000    5.000000  4027.000000
#
#        Member years
# count    504.000000
# mean       0.767857
# std       80.692897
# min    -1806.000000
# 25%        2.000000
# 50%        4.000000
# 75%        6.000000
# max       13.000000

# %%
#start index from 1
df.index+=1

# %%
df.head()
# Out:
#   User country  Nr. reviews  Nr. hotel reviews  Helpful votes  Score  \
# 1          USA           11                  4             13      5
# 2          USA          119                 21             75      3
# 3          USA           36                  9             25      5
# 4           UK           14                  7             14      4
# 5       Canada            5                  5              2      4
#
#   Period of stay Traveler type Swimming Pool Exercise Room Basketball Court  \
# 1        Dec-Feb       Friends            NO           YES               NO
# 2        Dec-Feb      Business            NO           YES               NO
# 3        Mar-May      Families            NO           YES               NO
# 4        Mar-May       Friends            NO           YES               NO
# 5        Mar-May          Solo            NO           YES               NO
#
#   Yoga Classes Club Free Wifi                              Hotel name  \
# ...

# %%
#column names
df.columns
# Out:
# Index(['User country', 'Nr. reviews', 'Nr. hotel reviews', 'Helpful votes',
#        'Score', 'Period of stay', 'Traveler type', 'Swimming Pool',
#        'Exercise Room', 'Basketball Court', 'Yoga Classes', 'Club',
#        'Free Wifi', 'Hotel name', 'Hotel stars', 'Nr. rooms', 'User continent',
#        'Member years', 'Review month', 'Review weekday'],
#       dtype='object')

# %%
#unique value in each column
for i in df.columns:
    print("Unique value in ",i,df[i].unique())
    print("---------------------------------------------------------------------------------------------------------------")
# Out:
# Unique value in  User country ['USA' 'UK' 'Canada' 'India' 'Australia' 'New Zeland' 'Ireland' 'Egypt'
#  'Finland' 'Kenya' 'Jordan' 'Netherlands' 'Syria' 'Scotland'
#  'South Africa' 'Swiss' 'United Arab Emirates' 'Hungary' 'China' 'Greece'
#  'Mexico' 'Croatia' 'Germany' 'Malaysia' 'Thailand' 'Phillippines'
#  'Israel' 'India ' 'Belgium' 'Puerto Rico' 'Switzerland' 'Norway' 'France'
#  'Spain' 'Singapore' 'Brazil' 'Costa Rica' 'Iran' 'Saudi Arabia'
#  'Honduras' 'Denmark' 'Taiwan' 'Hawaii' 'Kuwait' 'Czech Republic' 'Japan'
#  'Korea' 'Italy']
# ---------------------------------------------------------------------------------------------------------------
# Unique value in  Nr. reviews [ 11 119  36  14   5  31  45   2  24  12 102  20   7  22   3 146   8   9
#   41  10   4  18  29 114  30  87  26  56  13  58  70   6 290  47  35  74
#   34 576 418  73  63  54  33 156  19  23   1  21  17  43  15  16  27  97
#   78  79  88  39 130  50 161 153  46  25  59  48 127 113 103  28  32  37
# ...

# %%
#how many times a particular value has repeated
for i in df.columns:
    print(df[i].value_counts())
    print("------------------------------------------------------------------------------")
# Out:
# USA                     217
# UK                       72
# Canada                   65
# Australia                36
# Ireland                  13
# India                    11
# Mexico                    8
# Germany                   7
# Egypt                     5
# New Zeland                5
# Brazil                    5
# Netherlands               4
# Singapore                 4
# Hawaii                    3
# Malaysia                  3
# Thailand                  3
# Finland                   3
# Israel                    3
# Norway                    3
# Costa Rica                2
# United Arab Emirates      2
# Scotland                  2
# Spain                     2
# Switzerland               2
# Hungary                   1
# Honduras                  1
# China                     1
# Taiwan                    1
# Kuwait                    1
# Czech Republic            1
# France                    1
# Puerto Rico               1
# Swiss                     1
# ...

# %% [markdown]
# In "Member year" column, I observed that one value is entered worng i.e., "-1806" since year number can't be negative.
# So this number can be replace by its mean of that column

# %%
#for excluding -1806 we have to add 1806 in total sum
total=df['Member years'].sum()+1806
print(total)
print(total/503)
# Out:
# 2193
# 4.359840954274354

# %%
df.at[76,'Member years']=4

# %%
df["Member years"].unique()
# Out:
# array([ 9,  3,  2,  6,  7,  4,  0,  5,  1, 10, 11,  8, 12, 13],
#       dtype=int64)

# %% [markdown]
# We have also observed that in "Hotel stars" column two values had inserted i.e,(3,5) and (4,5) we can convert those value to (3+5)/2 = 4 and(4+5)/2 = 4 respectively

# %%
def change(x):
    if(x[0]=='3' and x[1]=='5'):
        return (3+5)//2
    elif(x[0]=='4' and x[1]=='5'):
        return (4+5)//2

# %%
cnt=0
for i in range(1,505):
    row=df.at[i,'Hotel stars']
    if(type(row)==str):
        row=list(row)
        row.remove(",")
        df.at[i,'Hotel stars']=change(row)
        cnt+=1
print(f"{cnt} values successfully changed!")
# Out:
# 96 values successfully changed!

# %%
df['Hotel stars'].unique()
# Out:
# array([3, 4, 5], dtype=object)

# %%
df_new=df

# %%
df_new['label']=df['Score']

# %%
df_new=df_new.drop(columns='Score',axis=1)

# %%
df_new.head()
# Out:
#   User country  Nr. reviews  Nr. hotel reviews  Helpful votes Period of stay  \
# 1          USA           11                  4             13        Dec-Feb
# 2          USA          119                 21             75        Dec-Feb
# 3          USA           36                  9             25        Mar-May
# 4           UK           14                  7             14        Mar-May
# 5       Canada            5                  5              2        Mar-May
#
#   Traveler type Swimming Pool Exercise Room Basketball Court Yoga Classes  \
# 1       Friends            NO           YES               NO           NO
# 2      Business            NO           YES               NO           NO
# 3      Families            NO           YES               NO           NO
# 4       Friends            NO           YES               NO           NO
# 5          Solo            NO           YES               NO           NO
#
# ...

# %% [markdown]
# Seperate feature and target vector

# %%
df_X=df_new.iloc[:,:19] #feature vector
df_y=df_new.iloc[:,19] #label vector

# %%
print(df_X.shape,df_y.shape)
# Out:
# (504, 19) (504,)

# %% [markdown]
# # Graphs

# %%
#number of scores
sns.countplot(df_y)

# %% [markdown]
# Hotel stars vs score

# %%
plt.figure(figsize=(12,6))
sns.countplot(df_X['Hotel stars'],hue=df_y)

# %%
sns.factorplot(x='label', col='Swimming Pool', kind='count', data=df_new)

# %%
sns.factorplot(x='label', col='Exercise Room', kind='count', data=df_new)

# %%
sns.factorplot(x='label', col='Basketball Court', kind='count', data=df_new)

# %%
sns.factorplot(x='label', col='Yoga Classes', kind='count', data=df_new)

# %%
sns.factorplot(x='label', col='Club', kind='count', data=df_new)

# %%
sns.factorplot(x='label', col='Free Wifi', kind='count', data=df_new)

# %%
#plt.figure(figsize=(20,6))
sns.factorplot(x='label', col='Traveler type', kind='count', data=df_new)

# %% [markdown]
# # Preprocessing stage

# %%
df_new
# Out:
#     User country  Nr. reviews  Nr. hotel reviews  Helpful votes  \
# 1            USA           11                  4             13
# 2            USA          119                 21             75
# 3            USA           36                  9             25
# 4             UK           14                  7             14
# 5         Canada            5                  5              2
# 6         Canada           31                  8             27
# 7             UK           45                 12             46
# 8            USA            2                  1              4
# 9          India           24                  3              8
# 10        Canada           12                  7             11
# 11           USA          102                 24             58
# 12     Australia           20                  9             24
# 13           USA            7                  6              9
# 14           USA           22                  5             13
# ...

# %% [markdown]
# Since we have more categorical data rather than numerical data, so we can apply one-hot-encoder to preprocess the datafram.

# %% [markdown]
# __Seperate feature and target vector__

# %%
df_feature=df_new.iloc[:,:19]
df_output=df_new.iloc[:,19]

# %%
#Pre-process the datafram using
from sklearn.preprocessing import LabelEncoder
df_dummies=pd.get_dummies(df_feature,drop_first=False)
#X_new = SelectFpr(chi2, alpha=0.05).fit_transform(df_dummies, df_output)

# %%
df_dummies.head()
# Out:
#    Nr. reviews  Nr. hotel reviews  Helpful votes  Nr. rooms  Member years  \
# 1           11                  4             13       3773             9
# 2          119                 21             75       3773             3
# 3           36                  9             25       3773             2
# 4           14                  7             14       3773             6
# 5            5                  5              2       3773             7
#
#    User country_Australia  User country_Belgium  User country_Brazil  \
# 1                       0                     0                    0
# 2                       0                     0                    0
# 3                       0                     0                    0
# 4                       0                     0                    0
# 5                       0                     0                    0
#
#    User country_Canada  User country_China            ...             \
# ...

# %%
df_output
# Out:
# 1      5
# 2      3
# 3      5
# 4      4
# 5      4
# 6      3
# 7      4
# 8      4
# 9      4
# 10     3
# 11     2
# 12     3
# 13     2
# 14     3
# 15     3
# 16     4
# 17     1
# 18     4
# 19     3
# 20     2
# 21     4
# 22     1
# 23     4
# 24     2
# 25     4
# 26     4
# 27     5
# 28     3
# 29     5
# 30     5
#       ..
# 475    2
# 476    5
# 477    4
# 478    5
# 479    5
# 480    4
# 481    4
# 482    3
# 483    4
# 484    3
# 485    5
# 486    5
# 487    4
# 488    4
# 489    3
# 490    4
# 491    4
# 492    3
# 493    4
# 494    5
# 495    3
# 496    4
# 497    5
# 498    3
# 499    5
# 500    5
# 501    4
# 502    4
# 503    2
# 504    4
# Name: label, Length: 504, dtype: int64

# %% [markdown]
# __separate training and testing data__

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df_dummies,df_output,test_size=0.2, random_state=21)

# %%
print("Training feature vector",X_train.shape)
print("Training target vector",y_train.shape)
print("Testing feature vector",X_test.shape)
print("Testing target vector",y_test.shape)
# Out:
# Training feature vector (403, 123)
# Training target vector (403,)
# Testing feature vector (101, 123)
# Testing target vector (101,)

# %%
X_train
# Out:
#      Nr. reviews  Nr. hotel reviews  Helpful votes  Nr. rooms  Member years  \
# 489           20                 17             21        826             4
# 494            9                  8              1        826             6
# 179           42                  8             22       3025             6
# 229          136                 20             55       1282             3
# 479          123                 26             63       2916             4
# 328           62                 40             25        732             5
# 478           24                  3              5       2916             0
# 40            24                  6              9       3981             2
# 401           14                  3             14        787             6
# 48            34                  8             30       3981             4
# 405           23                  9             23        787             4
# ...

# %% [markdown]
# # Build Deep Neural Network
# __for MultiClass__

# %%
# Importing Keras Sequential Model
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn import metrics
from keras.wrappers.scikit_learn import KerasClassifier

# %%
seed = 7
np.random.seed(seed)

# %% [markdown]
# Convert target vector to one-hot-encoded so that it can fit for our model

# %%
from keras.utils import np_utils
from sklearn.preprocessing import LabelEncoder
#for y_train
encoder=LabelEncoder().fit(y_train)
y_train_encoded=encoder.transform(y_train)
#convert integer to dummy variable
y_train_dummy=np_utils.to_categorical(y_train_encoded)



#for y_test
encoder=LabelEncoder().fit(y_test)
y_test_encoded=encoder.transform(y_test)
#convert integer to dummy variable
y_test_dummy=np_utils.to_categorical(y_test_encoded)

# %% [markdown]
# ___Creation of deep neural network___

# %%
def create_model():
    #initialize model
    model = Sequential()
    # Creating a 256 neuron hidden layer with Linear Rectified activation function.
    model.add(Dense(256, input_dim=123, init='uniform', activation='relu'))
    model.add(Dropout(0.3))
    # Creating a 128 neuron hidden layer.
    model.add(Dense(128, init='uniform', activation='relu'))
    model.add(Dropout(0.3))
    # Creating a 64 neuron hidden layer.
    model.add(Dense(64, init='uniform', activation='relu'))
    model.add(Dropout(0.3))
    # Adding a output layer.
    model.add(Dense(5, init='uniform', activation='softmax'))
    # Compiling the model
    model.compile(loss='binary_crossentropy',optimizer='adam', metrics=['accuracy'])
    model.summary()
    return model

# %% [markdown]
# I used the binary_crossentropy loss and not the usual categorical_crossentropy loss which is used in multi-class classification. This might seem unreasonable, but we want to penalize each output node independantly. So I pick a binary loss and model the output of the network as a independent bernoulli distributions per label.

# %%
model = create_model()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_106 (Dense)            (None, 256)               31744
# _________________________________________________________________
# dropout_79 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_107 (Dense)            (None, 128)               32896
# _________________________________________________________________
# dropout_80 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_108 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dropout_81 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_109 (Dense)            (None, 5)                 325
# ...
# Total params: 73,221
# ...

# %%
model.fit(X_train,y_train_dummy,validation_data=(X_test,y_test_dummy),epochs=20,batch_size=120)
# Out:
# Train on 403 samples, validate on 101 samples
# Epoch 1/20
# 403/403 [==============================] - 3s 7ms/step - loss: 0.5642 - acc: 0.7787 - val_loss: 0.4510 - val_acc: 0.7762
# Epoch 2/20
# 403/403 [==============================] - 0s 137us/step - loss: 0.4827 - acc: 0.7911 - val_loss: 0.4454 - val_acc: 0.8000
# Epoch 3/20
# 403/403 [==============================] - 0s 119us/step - loss: 0.4667 - acc: 0.7891 - val_loss: 0.4458 - val_acc: 0.7762
# Epoch 4/20
# 403/403 [==============================] - 0s 104us/step - loss: 0.4519 - acc: 0.7926 - val_loss: 0.4406 - val_acc: 0.7762
# Epoch 5/20
# 403/403 [==============================] - 0s 127us/step - loss: 0.4536 - acc: 0.7856 - val_loss: 0.4375 - val_acc: 0.8000
# Epoch 6/20
# 403/403 [==============================] - 0s 99us/step - loss: 0.4535 - acc: 0.7926 - val_loss: 0.4365 - val_acc: 0.8000
# Epoch 7/20
# ...

# %% [markdown]
# __Evaluation__

# %%
score=model.evaluate(X_test,y_test_dummy,verbose=0)

# %%
score
# Out:
# [0.42568344674488107, 0.801980198609947]

# %%
#Accuracy
score[1]
# Out:
# 0.801980198609947

# %% [markdown]
# __Evaluation using KFold__

# %%
estimator = KerasClassifier(build_fn=create_model, epochs=200, batch_size=5, verbose=0)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
kfold = KFold(n_splits=10, shuffle=True, random_state=seed)
results = cross_val_score(estimator, X_test, y_test_dummy, cv=kfold)
print("Baseline: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_54 (Dense)             (None, 256)               31744
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_55 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_56 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_57 (Dense)             (None, 5)                 325
# ...
# Total params: 73,221
# ...

# %% [markdown]
# The results are summarized as both the mean and standard deviation of the model accuracy on the dataset
